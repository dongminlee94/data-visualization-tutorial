# %% [markdown]
# # Matplotlib
# - Visualization 데이터 시각화
# - 파이썬의 대표적인 시각화 도구
# - 다양한 graph 지원
# - Pandas 연동

# %% [markdown]
# # 기본 사용법

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Figure의 구성 요소
#
# <img src="../img/elements_of_figure.png" width="600">

# %% [markdown]
# ## Set plot

# %% [markdown]
# ### 기본 plot
#
# - pyplot 객체를 사용하여 데이터를 표시
# - pyplot 객체에 그래프들을 쌓은 다음 show로 flush
# - pyplot 객체 사용시, 기본 figure에 그래프가 그려짐

# %%
X = range(100)
Y = range(100)

# %%
plt.plot(X, Y)
plt.show()

# %% [markdown]
# ### Figure 1개 - Axes 1개 - Plot 2개

# %%
X_1 = range(100)
Y_1 = [np.cos(value) for value in X]

# %%
X_2 = range(100)
Y_2 = [np.sin(value) for value in X]

# %%
plt.plot(X_1, Y_1)
plt.plot(X_2, Y_2)
plt.show()

# %% [markdown]
# ### Figure 1개 - Axes 2개 - Plot 2개
#
# - add_subplot를 이용하여 전체 figure 안에 sub-figure를 둘 수 있다.

# %% [markdown]
# <img src="../../img/axes_axis.png" width="300">

# %%
fig = plt.figure()  # figure 반환
fig.set_size_inches(10, 5)  # 크기지정

ax_1 = fig.add_subplot(1, 2, 1)  # 두개의 plot 생성
ax_2 = fig.add_subplot(1, 2, 2)  # 두개의 plot 생성

ax_1.plot(X_1, Y_1, c="b")  # 첫번째 plot
ax_2.plot(X_2, Y_2, c="g")  # 두번째 plot
plt.show()

# %% [markdown]
# ## Set color
#
# - Color 속성을 사용
# - Float -> 흑백, rgb color, predefined color 사용(ex. r - red, g - green, b - blue)
# - http://matplotlib.org/2.0.2/api/colors_api.html

# %%
X_1 = range(100)
Y_1 = [value for value in X_1]

X_2 = range(100)
Y_2 = [value + 100 for value in X_2]

# %%
plt.plot(X_1, Y_1, color="#2EFE2E")
plt.plot(X_2, Y_2, color="r")
plt.show()

# %% [markdown]
# ## Set linstyle
#
# - ls 또는 linestyle 속성 사용
# - https://matplotlib.org/examples/lines_bars_and_markers/linestyles.html

# %%
plt.plot(X_1, Y_1, c="b", linestyle="dashed")  # c = color
plt.plot(X_2, Y_2, c="r", ls="dotted")
plt.show()

# %% [markdown]
# ## Set title
#
# - Pyplot에 title함수 사용, figure의 subplot별 입력 가능

# %% [markdown]
# ### 기본 사용법

# %%
X_1 = range(100)
Y_1 = [value for value in X_1]

X_2 = range(100)
Y_2 = [value + 100 for value in X_2]

# %%
plt.plot(X_1, Y_1, color="b", linestyle="dashed")
plt.plot(X_2, Y_2, color="r", linestyle="dotted")

plt.title("Two lines")
plt.show()

# %% [markdown]
# ### 수식 표현
#
# - Latex 타입의 표현도 가능 (수식 표현 가능)

# %%
plt.plot(X_1, Y_1, color="b", linestyle="dashed")
plt.plot(X_2, Y_2, color="r", linestyle="dotted")

plt.title('$y = \\frac{ax + b}{test}$')
plt.show()

# %% [markdown]
# ### Title & Labels

# %%
plt.plot(X_1, Y_1, color="b", linestyle="dashed")
plt.plot(X_2, Y_2, color="r", linestyle="dotted")

plt.title('$y = ax+b$')
plt.xlabel('$x_line$')
plt.ylabel('y_line')

plt.show()

# %% [markdown]
# ## Set legend
#
# - Legend 함수로 범례를 표시함, loc 위치등 속성 지정

# %%
plt.plot(X_1, Y_1, color="b", linestyle="dashed", label='line_1')
plt.plot(X_2, Y_2, color="r", linestyle="dotted", label='line_2')

# loc = location - "lower right" 도 가능
plt.legend(shadow=True, fancybox=True, loc="upper right")

plt.title('$y = ax+b$')
plt.xlabel('$x_line$')
plt.ylabel('y_line')

plt.show()

# %% [markdown]
# ## Set grid & xylim
#
# - Graph 보조선을 긋는 grid와 xy축 범위 한계를 지정

# %%
plt.plot(X_1, Y_1, color="b", linestyle="dashed", label='line_1')
plt.plot(X_2, Y_2, color="r", linestyle="dotted", label='line_2')
plt.legend(shadow=True, fancybox=True, loc="lower right")

plt.grid(True, lw=0.4, ls="--", c=".90")
plt.xlim(-100, 200)
plt.ylim(-200, 200)

plt.show()

# %% [markdown]
# # Matplotlib Graph

# %% [markdown]
# ## Scatter
#
# - scatter 함수 사용, marker로 scatter 모양지정

# %% [markdown]
# ### 기본 scatter 그리기

# %%
# random samples from a uniform distribution over [0, 1)
data_1 = np.random.rand(512, 2)
data_2 = np.random.rand(512, 2)

# %%
plt.scatter(data_1[:, 0], data_1[:, 1], c="b", marker="x")
plt.scatter(data_2[:, 0], data_2[:, 1], c="r", marker="o")
plt.show()

# %% [markdown]
# ### area로 크기 정하기
#
# - area의 값에 따라서 s에 크기를 지정하여 비교할 수 있다.

# %%
N = 50

x = np.random.rand(N)
y = np.random.rand(N)

area = np.pi * (15 * np.random.rand(N))**2
colors = np.random.rand(N)

plt.scatter(x, y, s=area, c=colors, alpha=0.5)  # s: 데이터의 크기를 지정, 데이터의 크기 비교 가능
plt.show()

# %% [markdown]
# ## Bar chart
#
# - Bar 함수 사용

# %% [markdown]
# ### Vertical bar

# %%
data = [[5., 25., 50., 20.], [4., 23., 51., 17], [6., 22., 52., 19]]

X = np.arange(0, 8, 2)  # [0 2 4 6]

# %%
plt.bar(X + 0.0, data[0], color='b', width=0.5)
plt.bar(X + 0.5, data[1], color='g', width=0.5)
plt.bar(X + 1.0, data[2], color='r', width=0.5)
plt.xticks(X + 0.5, ("A", "B", "C", "D"))
plt.show()

# %% [markdown]
# ### Horizontal bar

# %%
data = np.array([[5., 25., 50., 20.], [4., 23., 51., 17], [6., 22., 52., 19]])
color_list = ['b', 'g', 'r']
data_label = ["A", "B", "C"]
X = np.arange(data.shape[1])

# %%
for i in range(data.shape[0]):
    plt.bar(X,
            data[i],
            bottom=np.sum(data[:i], axis=0),
            color=color_list[i],
            label=data_label[i])
plt.legend()
plt.show()

# %% [markdown]
# ## Histogram

# %%
# random floats sampled from a univariate “normal” (Gaussian) distribution of mean 0 and variance 1
X = np.random.randn(100)

plt.hist(X, bins=100)  # bins - 데이터를 나누는 개수
plt.show()

# %% [markdown]
# ## Boxplot
# - 출력된 그림을 보면 가운데 네모칸으로 되어있는 칸에 50%의 데이터가 있고, 위아래로 나머지 데이터들이 분포되어있다고 보면 됨
# - 네모칸 안에 노란색은 평균값
# - 양 끝에 보면 o 라는 것도 시각화가 되어있는데 outlier를 표현

# %%
data = np.random.randn(100, 5)

plt.boxplot(data)
plt.show()

# %% [markdown]
# # Matplotlib with pandas
#
# - Pandas 0.7 버전이상 부터 matplotlib를 사용한 그래프 지원
# - Dataframe, series별로 그래프 작성 가능

# %% [markdown]
# ## Import

# %%
import pandas as pd

# %% [markdown]
# ## 데이터 불러오기

# %%
data_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data'
df_data = pd.read_csv(data_url, sep='\s+', header=None)
df_data.columns = [
    'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
    'PTRATIO', 'B', 'LSTAT', 'MEDV'
]
# Column Header 이름 지정

# %%
df_data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# ## Scatter 이용하여 상관관계 보기
# - 데이터간의 상관관계를 볼 때 scatter graph 사용 가능

# %%
fig = plt.figure()  # figure 반환
ax = []

for i in range(1, 5):
    ax.append(fig.add_subplot(2, 2, i))  # 4개의 plot 생성

ax[0].scatter(df_data["CRIM"], df_data["MEDV"])
ax[1].scatter(df_data["PTRATIO"], df_data["MEDV"])
ax[2].scatter(df_data["AGE"], df_data["MEDV"])
ax[3].scatter(df_data["NOX"], df_data["MEDV"])
plt.show()

# %% [markdown]
# ## Axes를 이용하여 여러 plot 그리기

# %%
fig = plt.figure()
fig.set_size_inches(10.0, 10.0, forward=True)
ax = []

for i in range(1, 5):
    ax.append(fig.add_subplot(2, 2, i))

columns = ["CRIM", "PTRATIO", "AGE", "NOX"]
colors = ["b", "g", "c", "r"]

for i in range(4):
    ax[i].scatter(df_data[columns[i]],
                  df_data["MEDV"],
                  color=colors[i],
                  label=columns[i])
    ax[i].legend()
    ax[i].set_title(columns[i])

plt.subplots_adjust(wspace=0, hspace=0)
plt.show()

# %% [markdown]
# ## 모든 데이터 그래프 보기
# - plot 함수를 사용하면 모든 데이터의 graph를 그림

# %%
df_data.plot()
plt.show()

# %% [markdown]
# ## Plot하고 histogram 같이 보기**

# %%
fig = plt.figure()
fig.set_size_inches(10, 5)

ax_1 = fig.add_subplot(1, 2, 1)
ax_2 = fig.add_subplot(1, 2, 2)

ax_1.plot(df_data["MEDV"])
ax_2.hist(df_data["MEDV"], bins=50)

ax_1.set_title("House price MEDV")
ax_2.set_title("House price MEDV")

plt.show()

# %% [markdown]
# ## scatter_matrix 이용하여 모든 데이터의 상관관계 보기
# - 가운데는 데이터들이 어떠한 분포를 가지고 있는지를 보여주고, 나머지들은 각각의 데이터들이 어떠한 상관관계를 가지고 있는지를 보여준다.

# %%
pd.plotting.scatter_matrix(df_data, diagonal="kde", alpha=1, figsize=(20, 20))
plt.show()
